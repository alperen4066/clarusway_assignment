# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="Rossum"></p>
#
#
# ____

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
ecom = pd.read_csv('data.csv',encoding= 'unicode_escape')

# %% [markdown]
# **Check the head of the DataFrame.**

# %%
ecom.head()
# Out:
#   InvoiceNo StockCode  ... CustomerID         Country
# 0    536365    85123A  ...    17850.0  United Kingdom
# 1    536365     71053  ...    17850.0  United Kingdom
# 2    536365    84406B  ...    17850.0  United Kingdom
# 3    536365    84029G  ...    17850.0  United Kingdom
# 4    536365    84029E  ...    17850.0  United Kingdom
#
# [5 rows x 8 columns]

# %% [markdown]
# ** How many rows and columns are there? **

# %%
ecom.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188074 entries, 0 to 188073
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    188074 non-null  object
#  1   StockCode    188074 non-null  object
#  2   Description  187311 non-null  object
#  3   Quantity     188074 non-null  int64
#  4   InvoiceDate  188074 non-null  object
#  5   UnitPrice    188074 non-null  float64
#  6   CustomerID   132166 non-null  float64
#  7   Country      188074 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 11.5+ MB

# %% [markdown]
# ** Show the statistical measurements of ecom dataset **

# %%
ecom.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  511146.000000  511146.000000  386271.000000
# mean        9.613856       4.580769   15288.854185
# std       157.083443      94.727518    1712.783746
# min    -74215.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13956.000000
# 50%         3.000000       2.080000   15159.000000
# 75%        10.000000       4.130000   16791.000000
# max     74215.000000   38970.000000   18287.000000

# %% [markdown]
# ** What is the average Purchase Price? **

# %%
ecom.UnitPrice.mean()
#ecom["UnitPrice"].mean()
# Out:
# 4.580769435731898

# %% [markdown]
# ** What were the highest and lowest purchase prices? **

# %%
ecom.UnitPrice.max()
# Out:
# 38970.0

# %%
ecom.UnitPrice.min()
# Out:
# -11062.06

# %% [markdown]
# ** List the country names and number of records belongs to each country **

# %%
ecom["Country"].value_counts()
# Out:
# United Kingdom          466714
# Germany                   9139
# France                    8061
# EIRE                      7803
# Spain                     2431
# Netherlands               2281
# Switzerland               2002
# Belgium                   1971
# Portugal                  1416
# Australia                 1259
# Norway                     945
# Italy                      789
# Channel Islands            750
# Finland                    652
# Cyprus                     618
# Sweden                     460
# Unspecified                446
# Austria                    394
# Denmark                    351
# Japan                      349
# Poland                     341
# Israel                     297
# Hong Kong                  288
# USA                        248
# Singapore                  229
# Iceland                    171
# Canada                     151
# Malta                      122
# Greece                     110
# United Arab Emirates        68
# European Community          61
# RSA                         58
# Lebanon                     45
# Lithuania                   35
# Brazil                      32
# Czech Republic              30
# Bahrain                     19
# Saudi Arabia                10
# Name: Country, dtype: int64

# %% [markdown]
# ** How many records are as Country United Kingdom? **

# %%
ecom[ecom["Country"]=='United Kingdom'].count()
# Out:
# InvoiceNo      495478
# StockCode      495478
# Description    494024
# Quantity       495478
# InvoiceDate    495478
# UnitPrice      495478
# CustomerID     361878
# Country        495478
# dtype: int64

# %% [markdown]
# ** Create a column named Total which shows the total amount of spend using UnitPrice and Quantity ? **

# %%
ecom["Total"] = ecom["UnitPrice"]*ecom["Quantity"]
ecom["Total"]
# Out:
# 0         15.30
# 1         20.34
# 2         22.00
# 3         20.34
# 4         20.34
#           ...
# 511142     1.25
# 511143     1.25
# 511144     1.25
# 511145     1.56
# 511146      NaN
# Name: Total, Length: 511147, dtype: float64

# %% [markdown]
# ** Show total spending amount according to the Countries **

# %%
ecom.groupby("Country")["Total"].sum()/1000
# Out:
# Country
# Australia                137.077270
# Austria                   10.154320
# Bahrain                    0.548400
# Belgium                   40.910960
# Brazil                     1.143600
# Canada                     3.666380
# Channel Islands           20.086290
# Cyprus                    12.946290
# Czech Republic             0.707720
# Denmark                   18.768140
# EIRE                     263.276820
# European Community         1.291750
# Finland                   22.326740
# France                   197.403900
# Germany                  221.698210
# Greece                     4.710520
# Hong Kong                 10.117040
# Iceland                    4.310000
# Israel                     7.907820
# Italy                     16.890510
# Japan                     35.340620
# Lebanon                    1.693880
# Lithuania                  1.661060
# Malta                      2.505470
# Netherlands              284.661540
# Norway                    35.163460
# Poland                     7.213140
# Portugal                  29.367020
# RSA                        1.002310
# Saudi Arabia               0.131170
# Singapore                  9.120390
# Spain                     54.774580
# Sweden                    36.595910
# Switzerland               56.385350
# USA                        1.730920
# United Arab Emirates       1.902280
# United Kingdom          8187.806364
# Unspecified                4.749790
# Name: Total, dtype: float64

# %% [markdown]
# ** Which Country spend least? **

# %%
ecom.groupby("Country")["Total"].sum().sort_values()[:1]
# Out:
# Country
# Saudi Arabia    131.17
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average of spending according to country with apply function? **

# %%
ecom.groupby("Country").Total.apply(np.mean)
# Out:
# Country
# Australia               108.877895
# Austria                  25.322494
# Bahrain                  28.863158
# Belgium                  19.773301
# Brazil                   35.737500
# Canada                   24.280662
# Channel Islands          26.499063
# Cyprus                   20.813971
# Czech Republic           23.590667
# Denmark                  48.247147
# EIRE                     32.122599
# European Community       21.176230
# Finland                  32.124806
# France                   23.069288
# Germany                  23.348943
# Greece                   32.263836
# Hong Kong                35.128611
# Iceland                  23.681319
# Israel                   26.625657
# Italy                    21.034259
# Japan                    98.716816
# Lebanon                  37.641778
# Lithuania                47.458857
# Malta                    19.728110
# Netherlands             120.059696
# Norway                   32.378877
# Poland                   21.152903
# Portugal                 19.333127
# RSA                      17.281207
# Saudi Arabia             13.117000
# Singapore                39.827031
# Spain                    21.624390
# Sweden                   79.211926
# Switzerland              28.164510
# USA                       5.948179
# United Arab Emirates     27.974706
# United Kingdom           16.525065
# Unspecified              10.649753
# Name: Total, dtype: float64

# %% [markdown]
# ** Calculate average,min,max of spending according to country with agg function? **

# %%
ecom.groupby("Country").Total.agg(["min","max","mean"])
# Out:
#                             min        max        mean
# Country
# Australia               -425.00    1718.40  108.877895
# Austria                  -21.25     360.00   25.322494
# Bahrain                 -205.74     205.74   28.863158
# Belgium                  -19.95     165.00   19.773301
# Brazil                    15.00     175.20   35.737500
# Canada                     2.50     550.94   24.280662
# Channel Islands         -293.00     408.00   26.499063
# Cyprus                  -320.69     320.69   20.813971
# Czech Republic           -35.76      70.80   23.590667
# Denmark                  -59.80     428.40   48.247147
# EIRE                   -1917.00    2365.20   32.122599
# European Community        -8.50      60.00   21.176230
# Finland                  -80.00     551.20   32.124806
# France                 -8322.12    4161.06   23.069288
# Germany                 -599.50     876.00   23.348943
# Greece                   -50.00     175.20   32.263836
# Hong Kong              -2653.95    2653.95   35.128611
# Iceland                    5.04     249.60   23.681319
# Israel                  -136.00     350.40   26.625657
# Italy                    -89.55     300.00   21.034259
# Japan                  -1591.20    3794.40   98.716816
# Lebanon                   10.20     153.00   37.641778
# Lithuania                 13.20     122.40   47.458857
# Malta                   -130.00     455.00   19.728110
# Netherlands             -266.40    4992.00  120.059696
# Norway                  -376.50     700.00   32.378877
# Poland                   -39.80     120.00   21.152903
# Portugal               -1241.98    1241.98   19.333127
# RSA                        0.00      38.25   17.281207
# Saudi Arabia             -14.75      19.80   13.117000
# Singapore              -3949.32    3949.32   39.827031
# Spain                  -1715.85    1350.00   21.624390
# Sweden                 -1188.00    1188.00   79.211926
# Switzerland             -179.00     360.00   28.164510
# USA                      -74.88      81.36    5.948179
# United Arab Emirates       3.48     153.00   27.974706
# United Kingdom       -168469.60  168469.60   16.525065
# Unspecified                0.19      69.36   10.649753

# %% [markdown]
# ** What is the max Total spending in whole dataset and show the records of that spending ?**

# %%
ecom.sort_values("Total",ascending=False).head(1)
# Out:
#       InvoiceNo StockCode  ...        InvoiceDate2    Total
# 61619    541431     23166  ... 2011-01-18 10:01:00  77183.6
#
# [1 rows x 10 columns]

# %% [markdown]
# ** How many people who live in Spain spend more than average Total ?**

# %%
ecom[(ecom["Total"]> ecom["Total"].mean()) & (ecom["Country"]=="Spain")].count()
# Out:
# InvoiceNo       726
# StockCode       726
# Description     726
# Quantity        726
# InvoiceDate     726
# UnitPrice       726
# CustomerID      726
# Country         726
# InvoiceDate2    726
# Total           726
# dtype: int64

# %% [markdown]
# ** Convert datatype of InvoiceDate to datetime and assign it to new column name InvoiceDate2**

# %%
ecom["InvoiceDate2"]=pd.to_datetime(ecom.InvoiceDate)
ecom["InvoiceDate2"]
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 511142   2011-11-29 15:09:00
# 511143   2011-11-29 15:09:00
# 511144   2011-11-29 15:09:00
# 511145   2011-11-29 15:09:00
# 511146                   NaT
# Name: InvoiceDate2, Length: 511147, dtype: datetime64[ns]

# %% [markdown]
# ** Take only date values (year-month-day) from InvoiceDate2 and assign it to a new column named date **

# %%
ecom["Date"] = pd.to_datetime(ecom.InvoiceDate2.dt.date)
ecom["Date"]
# Out:
# 0        2010-12-01
# 1        2010-12-01
# 2        2010-12-01
# 3        2010-12-01
# 4        2010-12-01
#             ...
# 511142   2011-11-29
# 511143   2011-11-29
# 511144   2011-11-29
# 511145   2011-11-29
# 511146          NaT
# Name: Date, Length: 511147, dtype: datetime64[ns]

# %% [markdown]
# ** drop InvoiceDate2 and InvoiceDate columns permanently **

# %%
ecom.drop(["InvoiceDate","InvoiceDate2"], axis=1, inplace=True)
ecom.head()
# Out:
#   InvoiceNo StockCode  ...  Total       Date
# 0    536365    85123A  ...  15.30 2010-12-01
# 1    536365     71053  ...  20.34 2010-12-01
# 2    536365    84406B  ...  22.00 2010-12-01
# 3    536365    84029G  ...  20.34 2010-12-01
# 4    536365    84029E  ...  20.34 2010-12-01
#
# [5 rows x 9 columns]

# %% [markdown]
# ** Remove A, B, G and E from StockCode in first 5 rows of ecom dataframe with a string method **

# %%
ecom.StockCode[:5].str.replace('A','').str.replace('B','').str.replace('G','').str.replace('E','')
# Out:
# 0    85123
# 1    71053
# 2    84406
# 3    84029
# 4    84029
# Name: StockCode, dtype: object

# %% [markdown]
# ** take only Total and date columns with loc and craete a new df named ecom2 **

# %%
ecom2 = ecom.loc[:,["Total","Date"]]
ecom2
# Out:
#         Total       Date
# 0       15.30 2010-12-01
# 1       20.34 2010-12-01
# 2       22.00 2010-12-01
# 3       20.34 2010-12-01
# 4       20.34 2010-12-01
# ...       ...        ...
# 511142   1.25 2011-11-29
# 511143   1.25 2011-11-29
# 511144   1.25 2011-11-29
# 511145   1.56 2011-11-29
# 511146    NaN        NaT
#
# [511147 rows x 2 columns]

# %% [markdown]
# ** take only InvoiceNo, CustomerID and Total columns with iloc and craete a new df named ecom3 **

# %%
ecom3 = ecom.iloc[:,[0,5,7]]
ecom3
# Out:
#        InvoiceNo  CustomerID  Total
# 0         536365     17850.0  15.30
# 1         536365     17850.0  20.34
# 2         536365     17850.0  22.00
# 3         536365     17850.0  20.34
# 4         536365     17850.0  20.34
# ...          ...         ...    ...
# 511142    579472     13521.0   1.25
# 511143    579472     13521.0   1.25
# 511144    579472     13521.0   1.25
# 511145    579472     13521.0   1.56
# 511146        57         NaN    NaN
#
# [511147 rows x 3 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with concat **

# %%
ecom_concat2_3= pd.concat([ecom2, ecom3], axis=1)
ecom_concat2_3
# Out:
#         Total       Date InvoiceNo  CustomerID  Total
# 0       15.30 2010-12-01    536365     17850.0  15.30
# 1       20.34 2010-12-01    536365     17850.0  20.34
# 2       22.00 2010-12-01    536365     17850.0  22.00
# 3       20.34 2010-12-01    536365     17850.0  20.34
# 4       20.34 2010-12-01    536365     17850.0  20.34
# ...       ...        ...       ...         ...    ...
# 511142   1.25 2011-11-29    579472     13521.0   1.25
# 511143   1.25 2011-11-29    579472     13521.0   1.25
# 511144   1.25 2011-11-29    579472     13521.0   1.25
# 511145   1.56 2011-11-29    579472     13521.0   1.56
# 511146    NaN        NaT        57         NaN    NaN
#
# [511147 rows x 5 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with merge. If memory error occurs take only first 400 rows from both DFs.**

# %%
ecom_merge_2_3 = pd.merge(ecom2.iloc[:400,:],ecom3.iloc[:400,:], on='Total', left_index=True , right_index=True)
ecom_merge_2_3
# Out:
#      Total       Date InvoiceNo  CustomerID
# 0    15.30 2010-12-01    536365     17850.0
# 1    20.34 2010-12-01    536365     17850.0
# 2    22.00 2010-12-01    536365     17850.0
# 3    20.34 2010-12-01    536365     17850.0
# 4    20.34 2010-12-01    536365     17850.0
# ..     ...        ...       ...         ...
# 395  15.00 2010-12-01    536404     16218.0
# 396  15.00 2010-12-01    536404     16218.0
# 397  15.00 2010-12-01    536404     16218.0
# 398  15.00 2010-12-01    536404     16218.0
# 399  15.00 2010-12-01    536404     16218.0
#
# [400 rows x 4 columns]

# %% [markdown]
# ** Combine ecom2 and ecom3 with join (inner)**

# %%
join_ecom2_3 = ecom2.join(ecom3, how="inner",lsuffix='_left',rsuffix='_right')
join_ecom2_3
# Out:
#         Total_left       Date InvoiceNo  CustomerID  Total_right
# 0            15.30 2010-12-01    536365     17850.0        15.30
# 1            20.34 2010-12-01    536365     17850.0        20.34
# 2            22.00 2010-12-01    536365     17850.0        22.00
# 3            20.34 2010-12-01    536365     17850.0        20.34
# 4            20.34 2010-12-01    536365     17850.0        20.34
# ...            ...        ...       ...         ...          ...
# 511142        1.25 2011-11-29    579472     13521.0         1.25
# 511143        1.25 2011-11-29    579472     13521.0         1.25
# 511144        1.25 2011-11-29    579472     13521.0         1.25
# 511145        1.56 2011-11-29    579472     13521.0         1.56
# 511146         NaN        NaT        57         NaN          NaN
#
# [511147 rows x 5 columns]

# %% [markdown]
# # Congrats!
